# %% [markdown]
# **Data prep**
#
# **2022: Week 4 The Prep School - Travel Plans**
#
# <a href = "https://preppindata.blogspot.com/2022/01/2022-week-4-prep-school-travel-plans.html" >Data source and requirements </a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Input the csv file**

# %%
data1= pd.read_csv("PD 2022 Wk 1 Input - Input2.csv")
data1.head(10)
# Out:
#    id pupil first name pupil last name  gender Date of Birth  \
# 0   1            Ronna         Nellies  Female    12/21/2013
# 1   2            Rusty       Andriulis    Male     7/21/2012
# 2   3          Roberta       Oakeshott  Female     12/4/2011
# 3   4             Lola       Rubinfajn    Male     6/29/2012
# 4   5           Kamila        Benedtti  Female     7/10/2012
# 5   6            Avery       Colebourn  Female     8/30/2012
# 6   7        Valentino          Klimko  Female    12/23/2014
# 7   8              Cal       Shearwood    Male     1/18/2015
# 8   9             King        Truswell  Female     9/14/2012
# 9  10           Towney        Stichall    Male      6/4/2015
#
#   Parental Contact Name_1 Parental Contact Name_2 Preferred Contact Employer  \
# 0                 Purcell                   Ketti                     Demizz
# 1                 Vassili                    Rivi                   Brainbox
# 2                    Lind                 Haskell                   Centidel
# 3                    Elie                   Tresa                   Edgeblab
# 4                   Adela                  Clevey                     Trudoo
# 5                 Dalenna                 Charley                   Linktype
# 6                 Arlette                Onofredo                Thoughtblab
# 7                Leontine                   Berne                 Browseblab
# 8                    Evvy                 Othelia                 Photospace
# 9                  Wendie                  Joyann                    Kwimbee
#
#    Parental Contact
# 0                 1
# 1                 1
# 2                 2
# 3                 2
# 4                 1
# 5                 1
# 6                 2
# 7                 2
# 8                 1
# 9                 2

# %%
data2= pd.read_csv("PD 2021 WK 1 to 4 ideas - Preferences of Travel.csv")
data2.head(10)
# Out:
#    Student ID          M         Tu          W         Th          F
# 0           1        Car        Car        Car        Car    Bycycle
# 1           2    Bicycle    Bicycle    Bicycle       Walk       Walk
# 2           3        Car    Bicycle       Carr       Walk        Car
# 3           4    Scooter    Scooter     Scootr    Scooter     Scoter
# 4           5    Bycycle       Carr     Scoter      Walkk     Scoter
# 5           6        Car        Car        Car        Car        Car
# 6           7       Walk       Walk      Wallk       Walk       WAlk
# 7           8        Car       Walk    Bicycle       Walk       Walk
# 8           9  Aeroplane  Aeroplane  Aeroplane  Aeroplane  Aeroplane
# 9          10        Car       Walk        Car       Walk        Car

# %% [markdown]
# **Join the data sets together to give us the grades per student**

# %%
data=pd.merge(data1,data2, left_on='id', right_on='Student ID')

# %% [markdown]
# **Remove the parental data fields, they aren't needed for the challenge this week**

# %%
data = data.drop(columns=["Parental Contact Name_1", "Parental Contact Name_2", "Preferred Contact Employer", "Parental Contact"])

# %% [markdown]
# **Change the weekdays from separate columns to one column of weekdays and one of the pupil's travel choice**

# %%
data = pd.melt(data, id_vars=['Student ID','pupil first name','pupil last name','gender','Date of Birth'], value_vars=["M","Tu","W","Th","F"],
                   var_name="Weekday", value_name='Method of Travel')
data
# Out:
#       Student ID pupil first name pupil last name  gender Date of Birth  \
# 0              1            Ronna         Nellies  Female    12/21/2013
# 1              2            Rusty       Andriulis    Male     7/21/2012
# 2              3          Roberta       Oakeshott  Female     12/4/2011
# 3              4             Lola       Rubinfajn    Male     6/29/2012
# 4              5           Kamila        Benedtti  Female     7/10/2012
# ...          ...              ...             ...     ...           ...
# 4995         996          Ninetta         Worling  Female     2/15/2015
# 4996         997         Stanford          Tinton  Female      4/9/2013
# 4997         998            Ertha         MacCook    Male    12/14/2013
# 4998         999           Lawton         Randles  Female    12/12/2011
# 4999        1000         Engracia         Pashbee  Female     9/23/2013
#
#      Weekday Method of Travel
# 0          M              Car
# 1          M          Bicycle
# 2          M              Car
# 3          M          Scooter
# 4          M          Bycycle
# ...      ...              ...
# 4995       F             WAlk
# 4996       F             Walk
# 4997       F          Bicycle
# 4998       F             Walk
# 4999       F              Car
#
# [5000 rows x 7 columns]

# %% [markdown]
# **Group the travel choices together to remove spelling mistakes**

# %%
data['Method of Travel'].value_counts()
# Out:
# Car                1586
# Walk               1035
# Bicycle             710
# Scoter              252
# Scooter             252
# Walkk               176
# Carr                169
# Bycycle             162
# Van                 162
# Scootr               84
# WAlk                 84
# Wallk                84
# Helicopter           72
# Mum's Shoulders      46
# Aeroplane            45
# Dad's Shoulders      24
# Helicopeter          24
# Waalk                24
# Skipped               3
# Hopped                3
# Jumped                3
# Name: Method of Travel, dtype: int64

# %%
data['Method of Travel'] = data['Method of Travel'].replace(['Walkk','Wallk','WAlk','Waalk'],'Walk')
data['Method of Travel'] = data['Method of Travel'].replace('Carr','Car')
data['Method of Travel'] = data['Method of Travel'].replace(['Scoter','Scootr'],'Scooter')
data['Method of Travel'] = data['Method of Travel'].replace('Helicopeter','Helicopter')
data['Method of Travel'] = data['Method of Travel'].replace('Bycycle','Bicycle')

# %% [markdown]
# **Create a Sustainable (non-motorised) vs Non-Sustainable (motorised) data field** <br>
# **Scooters are the child type rather than the motorised type**

# %%
data.loc[(data['Method of Travel'] =='Walk') | (data['Method of Travel'] =='Bicycle') | (data['Method of Travel'] =='Scooter')| (data['Method of Travel'] =='Jumped')| (data['Method of Travel'] =='Skipped')| (data['Method of Travel'] =='Hopped') | (data['Method of Travel'] =="Dad's Shoulders") | (data['Method of Travel'] =="Mum's Shoulders"), 'Sustainable?'] = 'Sustainable'  
data.loc[(data['Method of Travel'] =='Car') | (data['Method of Travel'] =='Van') | (data['Method of Travel'] =='Helicopter')| (data['Method of Travel'] =='Aeroplane'), 'Sustainable?'] = 'Non-Sustainable'

# %% [markdown]
# **Total up the number of pupil's travelling by each method of travel**

# %%
df=pd.DataFrame(data.groupby(["Sustainable?", "Method of Travel", "Weekday"])['Student ID'].count().reset_index())
df.columns=["Sustainable?", "Method of Travel", "Weekday","Number of Trips"]

# %% [markdown]
# **Work out the % of trips taken by each method of travel each day <br>
# Round to 2 decimal places**

# %%
df["Trips per day"] = 1000
df["% trips per day"]=(df["Number of Trips"]/df["Trips per day"]).round(decimals = 2)

# %% [markdown]
# **Remove any unnecessary columns of data**
#
# **Output the data**

# %%
df
# Out:
#        Sustainable? Method of Travel Weekday  Number of Trips  Trips per day  \
# 0   Non-Sustainable        Aeroplane       F                9           1000
# 1   Non-Sustainable        Aeroplane       M                9           1000
# 2   Non-Sustainable        Aeroplane      Th                9           1000
# 3   Non-Sustainable        Aeroplane      Tu                9           1000
# 4   Non-Sustainable        Aeroplane       W                9           1000
# 5   Non-Sustainable              Car       F              254           1000
# 6   Non-Sustainable              Car       M              422           1000
# 7   Non-Sustainable              Car      Th              302           1000
# 8   Non-Sustainable              Car      Tu              364           1000
# 9   Non-Sustainable              Car       W              413           1000
# 10  Non-Sustainable       Helicopter       M               72           1000
# 11  Non-Sustainable       Helicopter      Th               24           1000
# 12  Non-Sustainable              Van       F               46           1000
# 13  Non-Sustainable              Van       M               37           1000
# 14  Non-Sustainable              Van      Tu               46           1000
# 15  Non-Sustainable              Van       W               33           1000
# 16      Sustainable          Bicycle       F              173           1000
# 17      Sustainable          Bicycle       M              210           1000
# 18      Sustainable          Bicycle      Th               62           1000
# 19      Sustainable          Bicycle      Tu              220           1000
# 20      Sustainable          Bicycle       W              207           1000
# 21      Sustainable  Dad's Shoulders      Th                9           1000
# 22      Sustainable  Dad's Shoulders      Tu               15           1000
# 23      Sustainable           Hopped       M                3           1000
# 24      Sustainable           Jumped       W                3           1000
# 25      Sustainable  Mum's Shoulders       F               24           1000
# 26      Sustainable  Mum's Shoulders       M                9           1000
# 27      Sustainable  Mum's Shoulders       W               13           1000
# 28      Sustainable          Scooter       F              168           1000
# 29      Sustainable          Scooter       M               84           1000
# 30      Sustainable          Scooter      Th               84           1000
# 31      Sustainable          Scooter      Tu               84           1000
# 32      Sustainable          Scooter       W              168           1000
# 33      Sustainable          Skipped      Tu                3           1000
# 34      Sustainable             Walk       F              326           1000
# 35      Sustainable             Walk       M              154           1000
# 36      Sustainable             Walk      Th              510           1000
# 37      Sustainable             Walk      Tu              259           1000
# 38      Sustainable             Walk       W              154           1000
#
#     % trips per day
# 0              0.01
# 1              0.01
# 2              0.01
# 3              0.01
# 4              0.01
# 5              0.25
# 6              0.42
# 7              0.30
# 8              0.36
# 9              0.41
# 10             0.07
# 11             0.02
# 12             0.05
# 13             0.04
# 14             0.05
# 15             0.03
# 16             0.17
# 17             0.21
# 18             0.06
# 19             0.22
# 20             0.21
# 21             0.01
# 22             0.02
# 23             0.00
# 24             0.00
# 25             0.02
# 26             0.01
# 27             0.01
# 28             0.17
# 29             0.08
# 30             0.08
# 31             0.08
# 32             0.17
# 33             0.00
# 34             0.33
# 35             0.15
# 36             0.51
# 37             0.26
# 38             0.15

# %%
#Output the data 
df.to_csv('PD 2022 Week 4 Output.csv', index=False)

# %%
print("Data Prepped!")
# Out:
# Data Prepped!
